# %%
import csv 
import json 
import pandas as pd

# %%
# Function to convert a CSV to JSON 
# Takes the file paths as arguments 
def make_json(csvFilePath, jsonFilePath): 
      
    # create a dictionary 
    data = {} 
      
    # Open a csv reader called DictReader 
    with open(csvFilePath, encoding='utf-8') as csvf: 
        csvReader = csv.DictReader(csvf) 
          
        # Convert each row into a dictionary  
        # and add it to data 
        for rows in csvReader: 
              
            # Assuming a column named 'No' to 
            # be the primary key 
            keys = rows['key'] 
            data[keys] = rows 
  
    # Open a json writer, and use the json.dumps()  
    # function to dump data 
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code 
  
# Decide the two file paths according to your  
# computer system 
csvFilePath = r'Final_Burrito.csv'
jsonFilePath = r'Burrito_JSON.json'
  
# Call the make_json function 
make_json(csvFilePath, jsonFilePath)

# %%
pd.read_json('Burrito_JSON.json')
# Out:
#                                       1                            2    \
# Location                       Albertacos                   Albertacos
# Burrito                       California                   Carne asada
# Neighborhood                   San Marcos                   San Marcos
# Address       500 W San Marcos Blvd # 103  500 W San Marcos Blvd # 103
# Yelp                                  3.5                          3.5
# Google                                3.9                          3.9
# Cost                                  5.7                         5.25
# key                                     1                            2
#
#                              3                   4                   5    \
# Location        Burros and Fries    Burros and Fries    Burros and Fries
# Burrito               California         Carne asada   Shrimp california
# Neighborhood          Clairemont          Clairemont          Clairemont
# Address       4705 Clairemont Dr  4705 Clairemont Dr  4705 Clairemont Dr
# Yelp                         3.5                 3.5                 3.5
# Google                       4.1                 4.1                 4.1
# Cost                        6.89                6.89                6.99
# key                            3                   4                   5
#
#                              6                         7    \
# Location        Burros and Fries     Caliente Mexican Food
# Burrito               California              carne asada
# Neighborhood          Clairemont           Sorrento Valley
# Address       4705 Clairemont Dr  11815 Sorrento Valley Rd
# Yelp                         3.5                       3.5
# Google                       4.1                       4.4
# Cost                        7.19                      5.56
# key                            6                         7
#
#                                    8                         9    \
# Location         Caliente Mexican Food     Caliente Mexican Food
# Burrito                   carne asada                 fried fish
# Neighborhood           Sorrento Valley           Sorrento Valley
# Address       11815 Sorrento Valley Rd  11815 Sorrento Valley Rd
# Yelp                               3.5                       3.5
# Google                             4.4                       4.4
# Cost                              5.56                      5.56
# key                                  8                         9
#
#                                    10   ...               299  \
# Location         Caliente Mexican Food  ...  Vallarta Express
# Burrito                     California  ...             Quesa
# Neighborhood           Sorrento Valley  ...        Clairemont
# Address       11815 Sorrento Valley Rd  ...  4277 Genesee Ave
# Yelp                               3.5  ...               3.5
# Google                             4.4  ...               4.0
# Cost                              6.47  ...              6.95
# key                                 10  ...               299
#
#                            300               301               302  \
# Location      Vallarta Express  Vallarta Express  Vallarta Express
# Burrito          Surf and turf              Mahi              Fish
# Neighborhood        Clairemont        Clairemont        Clairemont
# Address       4277 Genesee Ave  4277 Genesee Ave  4277 Genesee Ave
# Yelp                       3.5               3.5               3.5
# Google                     4.0               4.0               4.0
# Cost                      7.65               7.3               6.5
# key                        300               301               302
#
#                            303               304               305  \
# Location      Vallarta Express  Vallarta Express  Vallarta Express
# Burrito             California        California        California
# Neighborhood        Clairemont        Clairemont        Clairemont
# Address       4277 Genesee Ave  4277 Genesee Ave  4277 Genesee Ave
# Yelp                       3.5               3.5               3.5
# Google                     4.0               4.0               4.0
# Cost                      6.65              6.95               7.5
# key                        303               304               305
#
#                            306               307               308
# Location      Vallarta Express  Vallarta Express  Vallarta Express
# Burrito            Surf & Turf        California        California
# Neighborhood        Clairemont        Clairemont        Clairemont
# Address       4277 Genesee Ave  4277 Genesee Ave  4277 Genesee Ave
# Yelp                       3.5               3.5               3.5
# Google                     4.0               4.0               4.0
# Cost                      8.55               7.8              8.35
# key                        306               307               308
#
# [8 rows x 308 columns]
